# %%
import glob
import numpy as np
from PIL import Image
import random
import matplotlib.pyplot as plt

FLICKR_LIST = glob.glob('/hhd3/ld/data/flickr30k-images/*.jpg')


NYU_LIST_A = glob.glob('/hhd3/ld/data/nyu_depth_v2/official_splits/test/*/rgb*.jpg')
NYU_LIST_B = glob.glob('/hhd3/ld/data/nyu_depth_v2/official_splits/test/*/sync_depth*.png')
ADE20K_LIST_A = glob.glob('/hhd3/ld/data/ade20k/images/validation/*.jpg')
ADE20K_LIST_B = glob.glob('/hhd3/ld/data/ade20k/annotations_with_color/validation/*.png')
COCO_LIST_A = glob.glob('/hhd3/ld/data/COCO2017/val2017/*.jpg')
COCO_LIST_B = glob.glob('/hhd3/ld/data/COCO2017/pano_sem_seg/panoptic_segm_train2017_with_color/*.png')

# %%
plt.imshow(plt.imread(random.choice(FLICKR_LIST)))
plt.title('FLICKR_LIST')
# Out:
# Text(0.5, 1.0, 'FLICKR_LIST')

# %%
import matplotlib.pyplot as plt

titles = ['FLICKR_LIST', 'NYU_LIST_A', 'NYU_LIST_B', 'ADE20K_LIST_A', 'ADE20K_LIST_B', 'COCO_LIST_A', 'COCO_LIST_B']

# Assuming you have a list of images called image_list
image_list = [plt.imread(random.choice(FLICKR_LIST)), plt.imread(random.choice(NYU_LIST_A)), plt.imread(random.choice(NYU_LIST_B)), 
              plt.imread(random.choice(ADE20K_LIST_A)), plt.imread(random.choice(ADE20K_LIST_B)), plt.imread(random.choice(COCO_LIST_A)), 
              plt.imread(random.choice(COCO_LIST_B))]

# Create a subplot grid with 1 row and 7 columns
fig, axes = plt.subplots(nrows=1, ncols=7, figsize=(21, 3))

# Loop through the images and display them in the subplots
for i, ax in enumerate(axes.flatten()):
    ax.imshow(image_list[i])
    ax.set_title(f'Image of {titles[i]}')
    ax.axis('off')

# Adjust the spacing between subplots and show the plot
plt.tight_layout()
plt.show()

# %%
import glob
import numpy as np
from PIL import Image
import random
import matplotlib.pyplot as plt

NYU_LIST_B = glob.glob('/hhd3/ld/data/nyu_depth_v2/official_splits/test/*/sync_depth*.png')
ADE20K_LIST_B = glob.glob('/hhd3/ld/data/ade20k/annotations_with_color/validation/*.png')
COCO_LIST_B = glob.glob('/hhd3/ld/data/COCO2017/pano_sem_seg/panoptic_segm_train2017_with_color/*.png')
BLANK_IMG = np.zeros((input_size, input_size, 3), dtype=np.float64)

# %%
nyu = Image.open(random.choice(NYU_LIST_B))
plt.imshow(nyu)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 nyu = Image.open(random.choice(NYU_LIST_B))
#       2 plt.imshow(nyu)
#
# NameError: name 'Image' is not defined
