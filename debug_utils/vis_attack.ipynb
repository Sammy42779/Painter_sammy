# %%
import numpy as np
import matplotlib.pyplot as plt

imagenet_mean = np.array([0.485, 0.456, 0.406])
imagenet_std = np.array([0.229, 0.224, 0.225])

# %%
np.load('/hhd3/ld/data/Painter_root/nyu_depth/attack_A/img2_prompt.npy').shape
# Out:
# (896, 448, 3)

# %%
plt.imshow(np.load('/hhd3/ld/data/Painter_root/nyu_depth/attack_A/img2_prompt.npy')* imagenet_std + imagenet_mean)

# %%
plt.imshow(np.load('/hhd3/ld/data/Painter_root/nyu_depth/321_attack_AC/img2_prompt_adv_8.npy')* imagenet_std + imagenet_mean)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(np.load('/hhd3/ld/data/Painter_root/nyu_depth/attack_A/409_img2_prompt_adv_32.npy'))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(np.load('/hhd3/ld/data/Painter_root/nyu_depth/attack_A/409_img2_prompt_adv_32.npy')* imagenet_std + imagenet_mean)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(np.load('/hhd3/ld/data/Painter_root/nyu_depth/attack_A/527_img2_prompt_adv_128.npy')* imagenet_std + imagenet_mean)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(np.load('/hhd3/ld/data/Painter_root/nyu_depth/attack_A/527_img2_prompt.npy')* imagenet_std + imagenet_mean)

# %%
np.load('/hhd3/ld/data/Painter_root/nyu_depth/attack_A/527_img2_prompt.npy')[448:,:,:]==np.load('/hhd3/ld/data/Painter_root/nyu_depth/attack_A/527_img2_prompt_adv_128.npy')[448:,:,:]
# Out:
# array([[[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        ...,
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
# ...

# %%
np.load('/hhd3/ld/data/Painter_root/nyu_depth/attack_A/527_img2_prompt.npy')[:448,:,:]==np.load('/hhd3/ld/data/Painter_root/nyu_depth/attack_A/527_img2_prompt_adv_128.npy')[:448,:,:]
# Out:
# array([[[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        ...,
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
# ...

# %%
attack_id = 'attack_A'
# seed = 176
# alpha = 8
seed = 527
alpha = 128

img_2_adv = np.load(f'/hhd3/ld/data/Painter_root/nyu_depth/{attack_id}/{seed}_img2_prompt_adv_{alpha}.npy') * imagenet_std + imagenet_mean
tgt_2 = np.load(f'/hhd3/ld/data/Painter_root/nyu_depth/{attack_id}/{seed}_tgt2_prompt.npy') * imagenet_std + imagenet_mean

test_img = np.concatenate((img_2_adv, tgt_2), axis=1)
plt.axis('off')
plt.title(f'{attack_id}: perturbation={alpha}/255')
plt.imshow(test_img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
attack_id = 'attack_C'
# seed = 176
# alpha = 8
seed = 149
alpha = 8

img_2 = np.load(f'/hhd3/ld/data/Painter_root/nyu_depth/{attack_id}_{alpha}/{seed}_img2_prompt.npy') * imagenet_std + imagenet_mean
img_2_adv = np.load(f'/hhd3/ld/data/Painter_root/nyu_depth/{attack_id}_{alpha}/{seed}_img2_prompt_adv.npy') * imagenet_std + imagenet_mean
tgt_2 = np.load(f'/hhd3/ld/data/Painter_root/nyu_depth/{attack_id}_{alpha}/{seed}_tgt2_prompt.npy') * imagenet_std + imagenet_mean

test_img = np.concatenate((img_2, img_2_adv, tgt_2), axis=1)
plt.axis('off')
plt.title(f'{attack_id}: perturbation={alpha}/255')
plt.imshow(test_img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
attack_id = 'attack_C'
# seed = 176
# alpha = 8
seed = 454
alpha = 128

img_2 = np.load(f'/hhd3/ld/data/Painter_root/nyu_depth/{attack_id}_{alpha}/{seed}_img2_prompt.npy') * imagenet_std + imagenet_mean
img_2_adv = np.load(f'/hhd3/ld/data/Painter_root/nyu_depth/{attack_id}_{alpha}/{seed}_img2_prompt_adv.npy') * imagenet_std + imagenet_mean
tgt_2 = np.load(f'/hhd3/ld/data/Painter_root/nyu_depth/{attack_id}_{alpha}/{seed}_tgt2_prompt.npy') * imagenet_std + imagenet_mean

test_img = np.concatenate((img_2, img_2_adv, tgt_2), axis=1)
plt.axis('off')
plt.title(f'{attack_id}: perturbation={alpha}/255')
plt.imshow(test_img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
attack_id = 'attack_B'
# seed = 176
# alpha = 8
seed = 454
alpha = 8

img_2 = np.load(f'/hhd3/ld/data/Painter_root/nyu_depth/{attack_id}_{alpha}/img2_prompt.npy') * imagenet_std + imagenet_mean
tgt_2 = np.load(f'/hhd3/ld/data/Painter_root/nyu_depth/{attack_id}_{alpha}/tgt2_prompt.npy') * imagenet_std + imagenet_mean
tgt_2[448:, :, :] = 0
tgt_2_adv = np.load(f'/hhd3/ld/data/Painter_root/nyu_depth/{attack_id}_{alpha}/tgt2_prompt_adv.npy') * imagenet_std + imagenet_mean
tgt_2_adv[448:, :, :] = 0

test_img = np.concatenate((img_2, tgt_2, tgt_2_adv), axis=1)
plt.axis('off')
plt.title(f'{attack_id}: perturbation={alpha}/255')
plt.imshow(test_img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
attack_id = 'attack_B'
# seed = 176
# alpha = 8
seed = 454
alpha = 128

img_2 = np.load(f'/hhd3/ld/data/Painter_root/nyu_depth/{attack_id}_{alpha}/img2_prompt.npy') * imagenet_std + imagenet_mean
tgt_2 = np.load(f'/hhd3/ld/data/Painter_root/nyu_depth/{attack_id}_{alpha}/tgt2_prompt.npy') * imagenet_std + imagenet_mean
tgt_2[448:, :, :] = 0
tgt_2_adv = np.load(f'/hhd3/ld/data/Painter_root/nyu_depth/{attack_id}_{alpha}/tgt2_prompt_adv.npy') * imagenet_std + imagenet_mean
tgt_2_adv[448:, :, :] = 0

test_img = np.concatenate((img_2, tgt_2, tgt_2_adv), axis=1)
plt.axis('off')
plt.title(f'{attack_id}: perturbation={alpha}/255')
plt.imshow(test_img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
attack_id = 'attack_A'
# seed = 176
# alpha = 8
seed = 454
alpha = 8

img_2 = np.load(f'/hhd3/ld/data/Painter_root/nyu_depth/{attack_id}_{alpha}/img2_prompt.npy') * imagenet_std + imagenet_mean
img_2_adv = np.load(f'/hhd3/ld/data/Painter_root/nyu_depth/{attack_id}_{alpha}/img2_prompt_adv.npy') * imagenet_std + imagenet_mean
tgt_2 = np.load(f'/hhd3/ld/data/Painter_root/nyu_depth/{attack_id}_{alpha}/tgt2_prompt.npy') * imagenet_std + imagenet_mean
tgt_2[448:, :, :] = 0

test_img = np.concatenate((img_2, img_2_adv, tgt_2), axis=1)
plt.axis('off')
plt.title(f'{attack_id}: perturbation={alpha}/255')
plt.imshow(test_img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
attack_id = 'attack_A'
# seed = 176
# alpha = 8
seed = 454
alpha = 128

img_2 = np.load(f'/hhd3/ld/data/Painter_root/nyu_depth/{attack_id}_{alpha}/img2_prompt.npy') * imagenet_std + imagenet_mean
img_2_adv = np.load(f'/hhd3/ld/data/Painter_root/nyu_depth/{attack_id}_{alpha}/img2_prompt_adv.npy') * imagenet_std + imagenet_mean
tgt_2 = np.load(f'/hhd3/ld/data/Painter_root/nyu_depth/{attack_id}_{alpha}/tgt2_prompt.npy') * imagenet_std + imagenet_mean
tgt_2[448:, :, :] = 0

test_img = np.concatenate((img_2, img_2_adv, tgt_2), axis=1)
plt.axis('off')
plt.title(f'{attack_id}: perturbation={alpha}/255')
plt.imshow(test_img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
attack_id = 'attack_AC'
# seed = 176
# alpha = 8
seed = 454
alpha = 128

img_2 = np.load(f'/hhd3/ld/data/Painter_root/nyu_depth/{attack_id}_{alpha}/img2_prompt.npy') * imagenet_std + imagenet_mean
img_2_adv = np.load(f'/hhd3/ld/data/Painter_root/nyu_depth/{attack_id}_{alpha}/img2_prompt_adv.npy') * imagenet_std + imagenet_mean
tgt_2 = np.load(f'/hhd3/ld/data/Painter_root/nyu_depth/{attack_id}_{alpha}/tgt2_prompt.npy') * imagenet_std + imagenet_mean
tgt_2[448:, :, :] = 0

test_img = np.concatenate((img_2, img_2_adv, tgt_2), axis=1)
plt.axis('off')
plt.title(f'{attack_id}: perturbation={alpha}/255')
plt.imshow(test_img)
