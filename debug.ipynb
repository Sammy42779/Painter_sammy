# %%
coco_val_x = "/hhd3/ld/data/COCO2017/val2017/000000000139.jpg"
coco_val_y = "/hhd3/ld/data/COCO2017/annotations/panoptic_val2017/000000000139.png"

import torch
import matplotlib.pyplot as plt

x = Image.open(coco_val_x).convert("RGB")
y = Image.open(coco_val_y).convert("RGB")

res, hres = 448, 448

# %%
x = x.resize((res, hres)) 
y = y.resize((res, hres))

# %%
plt.imshow(plt.imread("/hhd3/ld/data/COCO2017/val2017/000000000139.jpg"))

# %%
plt.imshow(plt.imread("/hhd3/ld/data/COCO2017/annotations/panoptic_train2017/000000391460.png"))

# %%
import torch
import matplotlib.pyplot as plt
rgb = torch.load('/ssd1/ld/ICCV2023/Painter_sammy/rgb.pt')
depth = torch.load('/ssd1/ld/ICCV2023/Painter_sammy/depth.pt')
output = torch.load('/ssd1/ld/ICCV2023/Painter_sammy/output.pt')


output = output.detach().cpu().squeeze()
output = torch.einsum('chw->hwc', output)

print(rgb.shape)

print(depth.shape)



plt.imshow(output.numpy())

# %%
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

# prompt_img = '/hhd3/ld/data/nyu_depth_v2/sync/study_room_0005b/sync_depth_00094.png'
query_img_gt = '/hhd3/ld/data/nyu_depth_v2/official_splits/test/foyer/sync_depth_00351.png'

query_img_gt = "/hhd3/ld/data/nyu_depth_v2/nyuv2_depth_inference_painter_vit_large.pth_study_room_0005b/rgb_00094/foyer_rgb_00351.png"

query_img_gt = Image.open(query_img_gt).convert("RGB")
plt.imshow(query_img_gt)

# %%
gt = Image.open(gt).convert("RGB")
plt.imshow(gt)

# %%
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

prompt_img = '/hhd3/ld/data/nyu_depth_v2/sync/study_room_0005b/sync_depth_00094.png'
query_img = '/hhd3/ld/data/nyu_depth_v2/official_splits/test/foyer/rgb_00351.jpg'

prompt_img = Image.open(prompt_img).convert("RGB")
query_img = Image.open(query_img).convert("RGB")

# %%
plt.imshow(prompt_img)

# %%
plt.imshow(query_img)

# %%
prompt_img = prompt_img.resize((448, 448))
prompt_img = np.array(prompt_img) / 255.  # [0,1]


query_img = query_img.resize((448, 448))
query_img = np.array(query_img) / 255.  # [0,1]

result = np.concatenate((prompt_img, query_img), axis=0)
plt.imshow(result)

# %%
result_uint8 = (result * 255).astype(np.uint8)
plt.imshow(result_uint8)

# %%
result_uint8.shape

# %%
import matplotlib.pyplot as plt

prompt_img = '/hhd3/ld/data/nyu_depth_v2/sync/study_room_0005b/sync_depth_00094.png'

img = plt.imshow(plt.imread(prompt_img))

# %%
from PIL import Image
img = Image.open('/hhd3/ld/data/nyu_depth_v2/sync/study_room_0005b/sync_depth_00094.png').convert("RGB")

# %%
import numpy as np
img = np.array(img)

# %%
np.amin(img),np.amax(img)

# %%
np.amin(img / 10000.)
np.amax(img / 10000.)

# %%
img[:,:,0] == img[:,:,1]

# %%
img.size

# %%
img = img.resize((448, 448))

# %%
type(img)

# %%
plt.imshow(img)

# %%
prompt_img = '/hhd3/ld/data/nyu_depth_v2/sync/study_room_0005b/rgb_00094.jpg'
img = plt.imread(prompt_img)

# %%
type(img)

# %%
img.shape

# %%
img

# %%
from PIL import Image
img = Image.open("/hhd3/ld/data/nyu_depth_v2/official_splits/test/foyer/sync_depth_00351.png").convert("RGB")
img.size
img = img.resize((448, 448))
img = np.array(img)

# %%
from PIL import Image
img = Image.open('/hhd3/ld/data/nyu_depth_v2/official_splits/test/foyer/rgb_00351.jpg').convert("RGB")
img.size
img = img.resize((448, 448))
img = np.array(img)

# %%
plt.imshow(img)

# %%
mask_token = torch.zeros(1, 1, 1, 1024)
torch.nn.init.normal_(mask_token, std=.02)

# %%
import glob
flickr = glob.glob('/hhd3/ld/data/flickr30k-images/*.jpg')

# %%
type(flickr)

# %%
len(flickr)

# %%
flickr[6667]

# %%
plt.imshow(plt.imread(flickr[6667]))

# %%
import matplotlib.pyplot as plt
img_0 = np.load('/ssd1/ld/ICCV2023/Painter_sammy/img2_prompt_exp_baseline_0.npy')
img_1 = np.load('/ssd1/ld/ICCV2023/Painter_sammy/img2_prompt_exp_baseline_1.npy')
img_2 = np.load('/ssd1/ld/ICCV2023/Painter_sammy/img2_prompt_exp_baseline_2.npy')

tgt_0 = np.load('/ssd1/ld/ICCV2023/Painter_sammy/tgt2_prompt_exp_baseline_0.npy')
tgt_1 = np.load('/ssd1/ld/ICCV2023/Painter_sammy/tgt2_prompt_exp_baseline_1.npy')
tgt_2 = np.load('/ssd1/ld/ICCV2023/Painter_sammy/tgt2_prompt_exp_baseline_2.npy')

# %%
plt.imshow(img_0)

# %%
plt.imshow(img_1)

# %%
plt.imshow(img_2)

# %%
plt.imshow(tgt_0)

# %%
plt.imshow(tgt_1)

# %%
plt.imshow(tgt_2)

# %%
import matplotlib.pyplot as plt
img_0 = np.load('/ssd1/ld/ICCV2023/Painter_sammy/img2_prompt_exp_baseline_0.npy')
img_1 = np.load('/ssd1/ld/ICCV2023/Painter_sammy/img2_prompt_exp_baseline_1.npy')
img_2 = np.load('/ssd1/ld/ICCV2023/Painter_sammy/img2_prompt_exp_baseline_2.npy')

tgt_0 = np.load('/ssd1/ld/ICCV2023/Painter_sammy/tgt2_prompt_exp_baseline_0.npy')
tgt_1 = np.load('/ssd1/ld/ICCV2023/Painter_sammy/tgt2_prompt_exp_baseline_1.npy')
tgt_2 = np.load('/ssd1/ld/ICCV2023/Painter_sammy/tgt2_prompt_exp_baseline_2.npy')

# %%
plt.imshow(img_0)

# %%
plt.imshow(img_1)

# %%
plt.imshow(img_2)

# %%
plt.imshow(tgt_0)

# %%
plt.imshow(tgt_1)

# %%
plt.imshow(tgt_2)

# %%
import matplotlib.pyplot as plt
img_0 = np.load('/ssd1/ld/ICCV2023/Painter_sammy/img2_prompt_exp_mapping_1_1_b_0.npy')
img_1 = np.load('/ssd1/ld/ICCV2023/Painter_sammy/img2_prompt_exp_mapping_1_1_b_1.npy')
img_2 = np.load('/ssd1/ld/ICCV2023/Painter_sammy/img2_prompt_exp_mapping_1_1_b_2.npy')

tgt_0 = np.load('/ssd1/ld/ICCV2023/Painter_sammy/tgt2_prompt_exp_mapping_1_1_b_0.npy')
tgt_1 = np.load('/ssd1/ld/ICCV2023/Painter_sammy/tgt2_prompt_exp_mapping_1_1_b_1.npy')
tgt_2 = np.load('/ssd1/ld/ICCV2023/Painter_sammy/tgt2_prompt_exp_mapping_1_1_b_2.npy')

# %%
plt.title('exp_mapping_b_img0')
plt.imshow(img_0)

# %%
plt.title('exp_mapping_b_tgt0')
plt.imshow(tgt_0)

# %%
plt.title('exp_mapping_b_img1')
plt.imshow(img_1)

# %%
plt.title('exp_mapping_b_tgt1')
plt.imshow(tgt_1)

# %%
plt.imshow(plt.imread("/hhd3/ld/data/nyu_depth_v2/sync/study_room_0005b/sync_depth_00094.png"))

# %%
import numpy as np

# 创建一个维度为[448, 448, 3]的空白图像（全零矩阵），数据类型为float64
blank_image = np.zeros((448, 448, 3), dtype=np.float64)

print(blank_image.shape)  # 输出图像的形状


plt.imshow(blank_image)

# %%
import glob

# %%
ade = glob.glob('/hhd3/ld/data/ade20k/annotations_detectron2/*/*.png')

# %%
len(ade)
# Out:
# 22210

# %%
ade = glob.glob('/hhd3/ld/data/ade20k/annotations/*/*.png')

# %%
len(ade)
# Out:
# 22210

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
anime = Image.open('/hhd3/ld/data/ade20k/AnimeGANv2/training/ADE_train_00009574_animeGAN.png').convert('RGB')

# %%
plt.imshow(anime)

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
anime_v1 = Image.open('/hhd3/ld/data/ade20k/AnimeGANv2/training/ADE_train_00009574_animeGAN_v1.png').convert('RGB')
plt.imshow(anime_v1)

# %%
anime.shape
# Out:
# (512, 512, 3)

# %%
anime/ 255.
# Out:
# array([[[0.3372549 , 0.21568627, 0.14901961],
#         [0.33333333, 0.21176471, 0.14509804],
#         [0.3372549 , 0.21176471, 0.14509804],
#         ...,
#         [0.44313725, 0.28627451, 0.20784314],
#         [0.43921569, 0.28627451, 0.20392157],
#         [0.43921569, 0.28235294, 0.20392157]],
#
#        [[0.3372549 , 0.21568627, 0.14901961],
#         [0.33333333, 0.21176471, 0.14509804],
#         [0.3372549 , 0.21176471, 0.14509804],
#         ...,
#         [0.44313725, 0.28627451, 0.20784314],
#         [0.44313725, 0.28627451, 0.20784314],
#         [0.43921569, 0.28627451, 0.20784314]],
#
#        [[0.33333333, 0.21176471, 0.14509804],
#         [0.33333333, 0.21176471, 0.14509804],
#         [0.33333333, 0.21176471, 0.14509804],
#         ...,
#         [0.43921569, 0.28627451, 0.20784314],
#         [0.43921569, 0.28627451, 0.20784314],
#         [0.44313725, 0.28627451, 0.20784314]],
#
#        ...,
#
#        [[0.15294118, 0.09019608, 0.09411765],
# ...
